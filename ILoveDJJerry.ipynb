# %%
# Load NeuroKit and other useful packages
import neurokit2 as nk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## P1胸式呼吸

# %%
# Get data
#匯入資料
data1 = pd.read_csv("P1-V1.csv")
data2 = pd.read_csv("P1-V2.csv")
data3 = pd.read_csv("P1-V3.csv")
data4 = pd.read_csv("P1-V4.csv")
data5 = pd.read_csv("P1-V5.csv")
data6 = pd.read_csv("P1-V6.csv")
data7 = pd.read_csv("P1-V7.csv")
data8 = pd.read_csv("P1-V8.csv")
data9 = pd.read_csv("P1-V9.csv")
data10 = pd.read_csv("P1-V10.csv")
data11 = pd.read_csv("P1-V11.csv")
data12 = pd.read_csv("P1-V12.csv")
data13 = pd.read_csv("P1-V13.csv")
data14 = pd.read_csv("P1-V14.csv")
data15 = pd.read_csv("P1-V15.csv")
data16 = pd.read_csv("P1-V16.csv")
data17 = pd.read_csv("P1-V17.csv")
data18 = pd.read_csv("P1-V18.csv")
data19 = pd.read_csv("P1-V19.csv")
data20 = pd.read_csv("P1-V20.csv")
data21 = pd.read_csv("P1-V21.csv")
data22 = pd.read_csv("P1-V22.csv")
data23 = pd.read_csv("P1-V23.csv")
data24 = pd.read_csv("P1-V24.csv")
data25 = pd.read_csv("P1-V25.csv")
data26 = pd.read_csv("P1-V26.csv")
data27 = pd.read_csv("P1-V27.csv")
data28 = pd.read_csv("P1-V28.csv")
data29 = pd.read_csv("P1-V29.csv")
data30 = pd.read_csv("P1-V30.csv")
#選取胸式呼吸值
rsp_chest1 = data1["D: Resp"]
rsp_chest2 = data2["D: Resp"]
rsp_chest3 = data3["D: Resp"]
rsp_chest4 = data4["D: Resp"]
rsp_chest5 = data5["D: Resp"]
rsp_chest6 = data6["D: Resp"]
rsp_chest7 = data7["D: Resp"]
rsp_chest8 = data8["D: Resp"]
rsp_chest9 = data9["D: Resp"]
rsp_chest10 = data10["D: Resp"]
rsp_chest11 = data11["D: Resp"]
rsp_chest12 = data12["D: Resp"]
rsp_chest13 = data13["D: Resp"]
rsp_chest14 = data14["D: Resp"]
rsp_chest15 = data15["D: Resp"]
rsp_chest16 = data16["D: Resp"]
rsp_chest17 = data17["D: Resp"]
rsp_chest18 = data18["D: Resp"]
rsp_chest19 = data19["D: Resp"]
rsp_chest20 = data20["D: Resp"]
rsp_chest21 = data21["D: Resp"]
rsp_chest22 = data22["D: Resp"]
rsp_chest23 = data23["D: Resp"]
rsp_chest24 = data24["D: Resp"]
rsp_chest25 = data25["D: Resp"]
rsp_chest26 = data26["D: Resp"]
rsp_chest27 = data27["D: Resp"]
rsp_chest28 = data28["D: Resp"]
rsp_chest29 = data29["D: Resp"]
rsp_chest30 = data30["D: Resp"]

# 圖式化 #sampling_rate=16
nk.signal_plot(rsp_chest1, sampling_rate=16)

# %%
# Clean signal
cleaned_chest1 = nk.rsp_clean(rsp_chest1, sampling_rate=16)
cleaned_chest2 = nk.rsp_clean(rsp_chest2, sampling_rate=16)
cleaned_chest3 = nk.rsp_clean(rsp_chest3, sampling_rate=16)
cleaned_chest4 = nk.rsp_clean(rsp_chest4, sampling_rate=16)
cleaned_chest5 = nk.rsp_clean(rsp_chest5, sampling_rate=16)
cleaned_chest6 = nk.rsp_clean(rsp_chest6, sampling_rate=16)
cleaned_chest7 = nk.rsp_clean(rsp_chest7, sampling_rate=16)
cleaned_chest8 = nk.rsp_clean(rsp_chest8, sampling_rate=16)
cleaned_chest9 = nk.rsp_clean(rsp_chest9, sampling_rate=16)
cleaned_chest10 = nk.rsp_clean(rsp_chest10, sampling_rate=16)
cleaned_chest11 = nk.rsp_clean(rsp_chest11, sampling_rate=16)
cleaned_chest12 = nk.rsp_clean(rsp_chest12, sampling_rate=16)
cleaned_chest13 = nk.rsp_clean(rsp_chest13, sampling_rate=16)
cleaned_chest14 = nk.rsp_clean(rsp_chest14, sampling_rate=16)
cleaned_chest15 = nk.rsp_clean(rsp_chest15, sampling_rate=16)
cleaned_chest16 = nk.rsp_clean(rsp_chest16, sampling_rate=16)
cleaned_chest17 = nk.rsp_clean(rsp_chest17, sampling_rate=16)
cleaned_chest18 = nk.rsp_clean(rsp_chest18, sampling_rate=16)
cleaned_chest19 = nk.rsp_clean(rsp_chest19, sampling_rate=16)
cleaned_chest20 = nk.rsp_clean(rsp_chest20, sampling_rate=16)
cleaned_chest21 = nk.rsp_clean(rsp_chest21, sampling_rate=16)
cleaned_chest22 = nk.rsp_clean(rsp_chest22, sampling_rate=16)
cleaned_chest23 = nk.rsp_clean(rsp_chest23, sampling_rate=16)
cleaned_chest24 = nk.rsp_clean(rsp_chest24, sampling_rate=16)
cleaned_chest25 = nk.rsp_clean(rsp_chest25, sampling_rate=16)
cleaned_chest26 = nk.rsp_clean(rsp_chest26, sampling_rate=16)
cleaned_chest27 = nk.rsp_clean(rsp_chest27, sampling_rate=16)
cleaned_chest28 = nk.rsp_clean(rsp_chest28, sampling_rate=16)
cleaned_chest29 = nk.rsp_clean(rsp_chest29, sampling_rate=16)
cleaned_chest30 = nk.rsp_clean(rsp_chest30, sampling_rate=16)
# Extract peaks
#在波峰-波峰做記號
df1, peaks_dict1 = nk.rsp_peaks(cleaned_chest1)
df2, peaks_dict2 = nk.rsp_peaks(cleaned_chest2)
df3, peaks_dict3 = nk.rsp_peaks(cleaned_chest3)
df4, peaks_dict4 = nk.rsp_peaks(cleaned_chest4)
df5, peaks_dict5 = nk.rsp_peaks(cleaned_chest5)
df6, peaks_dict6 = nk.rsp_peaks(cleaned_chest6)
df7, peaks_dict7 = nk.rsp_peaks(cleaned_chest7)
df8, peaks_dict8 = nk.rsp_peaks(cleaned_chest8)
df9, peaks_dict9 = nk.rsp_peaks(cleaned_chest9)
df10, peaks_dict10 = nk.rsp_peaks(cleaned_chest10)
df11, peaks_dict11 = nk.rsp_peaks(cleaned_chest11)
df12, peaks_dict12 = nk.rsp_peaks(cleaned_chest12)
df13, peaks_dict13 = nk.rsp_peaks(cleaned_chest13)
df14, peaks_dict14 = nk.rsp_peaks(cleaned_chest14)
df15, peaks_dict15 = nk.rsp_peaks(cleaned_chest15)
df16, peaks_dict16 = nk.rsp_peaks(cleaned_chest16)
df17, peaks_dict17 = nk.rsp_peaks(cleaned_chest17)
df18, peaks_dict18 = nk.rsp_peaks(cleaned_chest18)
df19, peaks_dict19 = nk.rsp_peaks(cleaned_chest19)
df20, peaks_dict20 = nk.rsp_peaks(cleaned_chest20)
df21, peaks_dict21 = nk.rsp_peaks(cleaned_chest21)
df22, peaks_dict22 = nk.rsp_peaks(cleaned_chest22)
df23, peaks_dict23 = nk.rsp_peaks(cleaned_chest23)
df24, peaks_dict24 = nk.rsp_peaks(cleaned_chest24)
df25, peaks_dict25 = nk.rsp_peaks(cleaned_chest25)
df26, peaks_dict26 = nk.rsp_peaks(cleaned_chest26)
df27, peaks_dict27 = nk.rsp_peaks(cleaned_chest27)
df28, peaks_dict28 = nk.rsp_peaks(cleaned_chest28)
df29, peaks_dict29 = nk.rsp_peaks(cleaned_chest29)
df30, peaks_dict30 = nk.rsp_peaks(cleaned_chest30)
info1 = nk.rsp_fixpeaks(peaks_dict1)
info2 = nk.rsp_fixpeaks(peaks_dict2)
info3 = nk.rsp_fixpeaks(peaks_dict3)
info4 = nk.rsp_fixpeaks(peaks_dict4)
info5 = nk.rsp_fixpeaks(peaks_dict5)
info6 = nk.rsp_fixpeaks(peaks_dict6)
info7 = nk.rsp_fixpeaks(peaks_dict7)
info8 = nk.rsp_fixpeaks(peaks_dict8)
info9 = nk.rsp_fixpeaks(peaks_dict9)
info10 = nk.rsp_fixpeaks(peaks_dict10)
info11 = nk.rsp_fixpeaks(peaks_dict11)
info12 = nk.rsp_fixpeaks(peaks_dict12)
info13 = nk.rsp_fixpeaks(peaks_dict13)
info14 = nk.rsp_fixpeaks(peaks_dict14)
info15 = nk.rsp_fixpeaks(peaks_dict15)
info16 = nk.rsp_fixpeaks(peaks_dict16)
info17 = nk.rsp_fixpeaks(peaks_dict17)
info18 = nk.rsp_fixpeaks(peaks_dict18)
info19 = nk.rsp_fixpeaks(peaks_dict19)
info20 = nk.rsp_fixpeaks(peaks_dict20)
info21 = nk.rsp_fixpeaks(peaks_dict21)
info22 = nk.rsp_fixpeaks(peaks_dict22)
info23 = nk.rsp_fixpeaks(peaks_dict23)
info24 = nk.rsp_fixpeaks(peaks_dict24)
info25 = nk.rsp_fixpeaks(peaks_dict25)
info26 = nk.rsp_fixpeaks(peaks_dict26)
info27 = nk.rsp_fixpeaks(peaks_dict27)
info28 = nk.rsp_fixpeaks(peaks_dict28)
info29 = nk.rsp_fixpeaks(peaks_dict29)
info30 = nk.rsp_fixpeaks(peaks_dict30)
formatted1 = nk.signal_formatpeaks(info1, desired_length=len(cleaned_chest1),peak_indices=info1["RSP_Peaks"])
formatted2 = nk.signal_formatpeaks(info2, desired_length=len(cleaned_chest2),peak_indices=info2["RSP_Peaks"])
formatted3 = nk.signal_formatpeaks(info3, desired_length=len(cleaned_chest3),peak_indices=info3["RSP_Peaks"])
formatted4 = nk.signal_formatpeaks(info4, desired_length=len(cleaned_chest4),peak_indices=info4["RSP_Peaks"])
formatted5 = nk.signal_formatpeaks(info5, desired_length=len(cleaned_chest5),peak_indices=info5["RSP_Peaks"])
formatted6 = nk.signal_formatpeaks(info6, desired_length=len(cleaned_chest6),peak_indices=info6["RSP_Peaks"])
formatted7 = nk.signal_formatpeaks(info7, desired_length=len(cleaned_chest7),peak_indices=info7["RSP_Peaks"])
formatted8 = nk.signal_formatpeaks(info8, desired_length=len(cleaned_chest8),peak_indices=info8["RSP_Peaks"])
formatted9 = nk.signal_formatpeaks(info9, desired_length=len(cleaned_chest9),peak_indices=info9["RSP_Peaks"])
formatted10 = nk.signal_formatpeaks(info10, desired_length=len(cleaned_chest10),peak_indices=info10["RSP_Peaks"])
formatted11 = nk.signal_formatpeaks(info11, desired_length=len(cleaned_chest11),peak_indices=info11["RSP_Peaks"])
formatted12 = nk.signal_formatpeaks(info12, desired_length=len(cleaned_chest12),peak_indices=info12["RSP_Peaks"])
formatted13 = nk.signal_formatpeaks(info13, desired_length=len(cleaned_chest13),peak_indices=info13["RSP_Peaks"])
formatted14 = nk.signal_formatpeaks(info14, desired_length=len(cleaned_chest14),peak_indices=info14["RSP_Peaks"])
formatted15 = nk.signal_formatpeaks(info15, desired_length=len(cleaned_chest15),peak_indices=info15["RSP_Peaks"])
formatted16 = nk.signal_formatpeaks(info16, desired_length=len(cleaned_chest16),peak_indices=info16["RSP_Peaks"])
formatted17 = nk.signal_formatpeaks(info17, desired_length=len(cleaned_chest17),peak_indices=info17["RSP_Peaks"])
formatted18 = nk.signal_formatpeaks(info18, desired_length=len(cleaned_chest18),peak_indices=info18["RSP_Peaks"])
formatted19 = nk.signal_formatpeaks(info19, desired_length=len(cleaned_chest19),peak_indices=info19["RSP_Peaks"])
formatted20 = nk.signal_formatpeaks(info20, desired_length=len(cleaned_chest20),peak_indices=info20["RSP_Peaks"])
formatted21 = nk.signal_formatpeaks(info21, desired_length=len(cleaned_chest21),peak_indices=info21["RSP_Peaks"])
formatted22 = nk.signal_formatpeaks(info22, desired_length=len(cleaned_chest22),peak_indices=info22["RSP_Peaks"])
formatted23 = nk.signal_formatpeaks(info23, desired_length=len(cleaned_chest23),peak_indices=info23["RSP_Peaks"])
formatted24 = nk.signal_formatpeaks(info24, desired_length=len(cleaned_chest24),peak_indices=info24["RSP_Peaks"])
formatted25 = nk.signal_formatpeaks(info25, desired_length=len(cleaned_chest25),peak_indices=info25["RSP_Peaks"])
formatted26 = nk.signal_formatpeaks(info26, desired_length=len(cleaned_chest26),peak_indices=info26["RSP_Peaks"])
formatted27 = nk.signal_formatpeaks(info27, desired_length=len(cleaned_chest27),peak_indices=info27["RSP_Peaks"])
formatted28 = nk.signal_formatpeaks(info28, desired_length=len(cleaned_chest28),peak_indices=info28["RSP_Peaks"])
formatted29 = nk.signal_formatpeaks(info29, desired_length=len(cleaned_chest29),peak_indices=info29["RSP_Peaks"])
formatted30 = nk.signal_formatpeaks(info30, desired_length=len(cleaned_chest30),peak_indices=info30["RSP_Peaks"])
print(info2)
# Out:
# {'RSP_Peaks': array([ 113,  178,  226,  278,  329,  378,  420,  453,  508,  541,  576,
#         634,  684,  753,  793,  835,  883,  930,  971, 1016, 1057, 1093,
#        1137, 1196, 1284, 1325, 1363, 1401, 1447, 1494, 1543, 1615, 1785,
#        1870, 1909, 1984, 2030], dtype=int64), 'RSP_Troughs': array([  93,  144,  213,  256,  310,  358,  395,  442,  490,  527,  561,
#         613,  664,  737,  775,  816,  863,  907,  952,  995, 1037, 1075,
#        1118, 1180, 1223, 1308, 1350, 1385, 1428, 1469, 1525, 1597, 1719,
#        1806, 1898, 1929, 1996], dtype=int64)}

# %%
nk.signal_plot(pd.DataFrame({"RSP_Raw":rsp_chest1, "RSP_Clean": cleaned_chest1}), sampling_rate=16, subplots=True)
nk.signal_plot(pd.DataFrame({"RSP_Raw":rsp_chest2, "RSP_Clean": cleaned_chest2}), sampling_rate=16, subplots=True)

#到這為止正確，我真聰明

# %%
Chest_peaks = nk.events_plot(peaks_dict1['RSP_Peaks'], cleaned_chest1)

# %%
# Extract rate
rsp_chest_rate = nk.rsp_rate(cleaned_chest1, peaks_dict1, sampling_rate=16)

# Visualize
nk.signal_plot(rsp_chest_rate, sampling_rate=16)
plt.ylabel('Breaths Per Minute')
# Out:
# Text(0, 0.5, 'Breaths Per Minute')

# %%
rrv = nk.rsp_rrv(rsp_chest_rate, info1, sampling_rate=16, show=True) #傅立葉分析

# %%
df1, info1 = nk.bio_process(rsp= data1["D: Resp"], sampling_rate=16)
df2, info2 = nk.bio_process(rsp= data2["D: Resp"], sampling_rate=16)
df3, info3 = nk.bio_process(rsp= data3["D: Resp"], sampling_rate=16)
df4, info4 = nk.bio_process(rsp= data4["D: Resp"], sampling_rate=16)
df5, info5 = nk.bio_process(rsp= data5["D: Resp"], sampling_rate=16)
df6, info6 = nk.bio_process(rsp= data6["D: Resp"], sampling_rate=16)
df7, info7 = nk.bio_process(rsp= data7["D: Resp"], sampling_rate=16)
df8, info8 = nk.bio_process(rsp= data8["D: Resp"], sampling_rate=16)
df9, info9 = nk.bio_process(rsp= data9["D: Resp"], sampling_rate=16)
df10, info10 = nk.bio_process(rsp= data10["D: Resp"], sampling_rate=16)
df11, info11 = nk.bio_process(rsp= data11["D: Resp"], sampling_rate=16)
df12, info12 = nk.bio_process(rsp= data12["D: Resp"], sampling_rate=16)
df13, info13 = nk.bio_process(rsp= data13["D: Resp"], sampling_rate=16)
df14, info14 = nk.bio_process(rsp= data14["D: Resp"], sampling_rate=16)
df15, info15 = nk.bio_process(rsp= data15["D: Resp"], sampling_rate=16)
df16, info16 = nk.bio_process(rsp= data16["D: Resp"], sampling_rate=16)
df17, info17 = nk.bio_process(rsp= data17["D: Resp"], sampling_rate=16)
df18, info18 = nk.bio_process(rsp= data18["D: Resp"], sampling_rate=16)
df19, info19 = nk.bio_process(rsp= data19["D: Resp"], sampling_rate=16)
df20, info20 = nk.bio_process(rsp= data20["D: Resp"], sampling_rate=16)
df21, info21 = nk.bio_process(rsp= data21["D: Resp"], sampling_rate=16)
df22, info22 = nk.bio_process(rsp= data22["D: Resp"], sampling_rate=16)
df23, info23 = nk.bio_process(rsp= data23["D: Resp"], sampling_rate=16)
df24, info24 = nk.bio_process(rsp= data24["D: Resp"], sampling_rate=16)
df25, info25 = nk.bio_process(rsp= data25["D: Resp"], sampling_rate=16)
df26, info26 = nk.bio_process(rsp= data26["D: Resp"], sampling_rate=16)
df27, info27 = nk.bio_process(rsp= data27["D: Resp"], sampling_rate=16)
df28, info28 = nk.bio_process(rsp= data28["D: Resp"], sampling_rate=16)
df29, info29 = nk.bio_process(rsp= data29["D: Resp"], sampling_rate=16)
df30, info30 = nk.bio_process(rsp= data30["D: Resp"], sampling_rate=16)

# %%
events1 = nk.events_find(data1["participant"], threshold_keep='below')
events2 = nk.events_find(data2["participant"], threshold_keep='below')
events3 = nk.events_find(data3["participant"], threshold_keep='below')
events4 = nk.events_find(data4["participant"], threshold_keep='below')
events5 = nk.events_find(data5["participant"], threshold_keep='below')
events6 = nk.events_find(data6["participant"], threshold_keep='below')
events7 = nk.events_find(data7["participant"], threshold_keep='below')
events8 = nk.events_find(data8["participant"], threshold_keep='below')
events9 = nk.events_find(data9["participant"], threshold_keep='below')
events10 = nk.events_find(data10["participant"], threshold_keep='below')
events11 = nk.events_find(data11["participant"], threshold_keep='below')
events12 = nk.events_find(data12["participant"], threshold_keep='below')
events13 = nk.events_find(data13["participant"], threshold_keep='below')
events14 = nk.events_find(data14["participant"], threshold_keep='below')
events15 = nk.events_find(data15["participant"], threshold_keep='below')
events16 = nk.events_find(data16["participant"], threshold_keep='below')
events17 = nk.events_find(data17["participant"], threshold_keep='below')
events18 = nk.events_find(data18["participant"], threshold_keep='below')
events19 = nk.events_find(data19["participant"], threshold_keep='below')
events20 = nk.events_find(data20["participant"], threshold_keep='below')
events21 = nk.events_find(data21["participant"], threshold_keep='below')
events22 = nk.events_find(data22["participant"], threshold_keep='below')
events23 = nk.events_find(data23["participant"], threshold_keep='below')
events24 = nk.events_find(data24["participant"], threshold_keep='below')
events25 = nk.events_find(data25["participant"], threshold_keep='below')
events26 = nk.events_find(data26["participant"], threshold_keep='below')
events27 = nk.events_find(data27["participant"], threshold_keep='below')
events28 = nk.events_find(data28["participant"], threshold_keep='below')
events29 = nk.events_find(data29["participant"], threshold_keep='below')
events30 = nk.events_find(data30["participant"], threshold_keep='below')

# %%
epochs1 = nk.epochs_create(df1, events1, sampling_rate=16)
epochs2 = nk.epochs_create(df2, events2, sampling_rate=16)
epochs3 = nk.epochs_create(df3, events3, sampling_rate=16)
epochs4 = nk.epochs_create(df4, events4, sampling_rate=16)
epochs5 = nk.epochs_create(df5, events5, sampling_rate=16)
epochs6 = nk.epochs_create(df6, events6, sampling_rate=16)
epochs7 = nk.epochs_create(df7, events7, sampling_rate=16)
epochs8 = nk.epochs_create(df8, events8, sampling_rate=16)
epochs9 = nk.epochs_create(df9, events9, sampling_rate=16)
epochs10 = nk.epochs_create(df10, events10, sampling_rate=16)
epochs11 = nk.epochs_create(df11, events11, sampling_rate=16)
epochs12 = nk.epochs_create(df12, events12, sampling_rate=16)
epochs13 = nk.epochs_create(df13, events13, sampling_rate=16)
epochs14 = nk.epochs_create(df14, events14, sampling_rate=16)
epochs15 = nk.epochs_create(df15, events15, sampling_rate=16)
epochs16 = nk.epochs_create(df16, events16, sampling_rate=16)
epochs17 = nk.epochs_create(df17, events17, sampling_rate=16)
epochs18 = nk.epochs_create(df18, events18, sampling_rate=16)
epochs19 = nk.epochs_create(df19, events19, sampling_rate=16)
epochs20 = nk.epochs_create(df20, events20, sampling_rate=16)
epochs21 = nk.epochs_create(df21, events21, sampling_rate=16)
epochs22 = nk.epochs_create(df22, events22, sampling_rate=16)
epochs23 = nk.epochs_create(df23, events23, sampling_rate=16)
epochs24 = nk.epochs_create(df24, events24, sampling_rate=16)
epochs25 = nk.epochs_create(df25, events25, sampling_rate=16)
epochs26 = nk.epochs_create(df26, events26, sampling_rate=16)
epochs27 = nk.epochs_create(df27, events27, sampling_rate=16)
epochs28 = nk.epochs_create(df28, events28, sampling_rate=16)
epochs29 = nk.epochs_create(df29, events29, sampling_rate=16)
epochs30 = nk.epochs_create(df30, events30, sampling_rate=16)

# %%
result1 = nk.rsp_eventrelated(epochs1)
result2 = nk.rsp_eventrelated(epochs2)
result3 = nk.rsp_eventrelated(epochs3)
result4 = nk.rsp_eventrelated(epochs4)
result5 = nk.rsp_eventrelated(epochs5)
result6 = nk.rsp_eventrelated(epochs6)
result7 = nk.rsp_eventrelated(epochs7)
result8 = nk.rsp_eventrelated(epochs8)
result9 = nk.rsp_eventrelated(epochs9)
result10 = nk.rsp_eventrelated(epochs10)
result11 = nk.rsp_eventrelated(epochs11)
result12 = nk.rsp_eventrelated(epochs12)
result13 = nk.rsp_eventrelated(epochs13)
result14 = nk.rsp_eventrelated(epochs14)
result15 = nk.rsp_eventrelated(epochs15)
result16 = nk.rsp_eventrelated(epochs16)
result17 = nk.rsp_eventrelated(epochs17)
result18 = nk.rsp_eventrelated(epochs18)
result19 = nk.rsp_eventrelated(epochs19)
result20 = nk.rsp_eventrelated(epochs20)
result21 = nk.rsp_eventrelated(epochs21)
result22 = nk.rsp_eventrelated(epochs22)
result23 = nk.rsp_eventrelated(epochs23)
result24 = nk.rsp_eventrelated(epochs24)
result25 = nk.rsp_eventrelated(epochs25)
result26 = nk.rsp_eventrelated(epochs26)
result27 = nk.rsp_eventrelated(epochs27)
result28 = nk.rsp_eventrelated(epochs28)
result29 = nk.rsp_eventrelated(epochs29)
result30 = nk.rsp_eventrelated(epochs30)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [49], in <cell line: 23>()
#      21 result21 = nk.rsp_eventrelated(epochs21)
#      22 result22 = nk.rsp_eventrelated(epochs22)
# ---> 23 result23 = nk.rsp_eventrelated(epochs23)
#      24 result24 = nk.rsp_eventrelated(epochs24)
#      25 result25 = nk.rsp_eventrelated(epochs25)
#
# File ~\.conda\envs\ml\lib\site-packages\neurokit2\rsp\rsp_eventrelated.py:97, in rsp_eventrelated(epochs, silent)
#      94 data[i] = {}  # Initialize empty container
#      96 # Rate
# ---> 97 data[i] = _eventrelated_rate(epochs[i], data[i], var="RSP_Rate")
#      99 # Amplitude
#     100 data[i] = _rsp_eventrelated_amplitude(epochs[i], data[i])
#
# File ~\.conda\envs\ml\lib\site-packages\neurokit2\epochs\eventrelated_utils.py:111, in _eventrelated_rate(epoch, output, var)
#     106 output[var + "_Min_Time"] = index[np.argmin(signal)]
# ...

# %%
result_df = pd.concat([result1, result2, result3, result4, result5, result6, result7, result8, result9, result10, result11, result12, result13, result14, result15, result16, result17, result19, result20, result21, result22, result23, result24, result25, result26, result27, result28, result29, result30], axis=0)
result_df.to_csv("P1_胸式呼吸_謝謝冠哲.csv",index=False)

# %%
print(epochs24)
# Out:
# {'1':            RSP_Raw  RSP_Clean  RSP_Amplitude  RSP_Rate   RSP_RVT  RSP_Phase  \
# 0.000000    37.518   0.072007       0.908053       NaN  0.104159        NaN
# 0.062782    37.523   0.078142       0.908053       NaN  0.104419        NaN
# 0.125563    37.528   0.085883       0.908053       NaN  0.104838        NaN
# 0.188345    37.537   0.095515       0.908053       NaN  0.105410        NaN
# 0.251126    37.546   0.104805       0.908053       NaN  0.106122        NaN
# ...            ...        ...            ...       ...       ...        ...
# 13.686374   38.326  -0.072479       0.662346       NaN  0.084601        NaN
# 13.749155   38.347  -0.053227       0.662346       NaN  0.084934        NaN
# 13.811937   38.374  -0.031559       0.662346       NaN  0.085196        NaN
# 13.874718   38.402  -0.008753       0.662346       NaN  0.085386        NaN
# 13.937500   38.427   0.014058       0.662346       NaN  0.085502        NaN
#
# ...

# %% [markdown]
# ## P1腹式呼吸

# %%
# Get data
rsp_abd1 = data1["E : Resp"]
rsp_abd2 = data2["E : Resp"]
rsp_abd3 = data3["E : Resp"]
rsp_abd4 = data4["E : Resp"]
rsp_abd5 = data5["E : Resp"]
rsp_abd6 = data6["E : Resp"]
rsp_abd7 = data7["E : Resp"]
rsp_abd8 = data8["E : Resp"]
rsp_abd9 = data9["E : Resp"]
rsp_abd10 = data10["E : Resp"]
rsp_abd11 = data11["E : Resp"]
rsp_abd12 = data12["E : Resp"]
rsp_abd13 = data13["E : Resp"]
rsp_abd14 = data14["E : Resp"]
rsp_abd15 = data15["E : Resp"]
rsp_abd16 = data16["E : Resp"]
rsp_abd17 = data17["E : Resp"]
rsp_abd18 = data18["E : Resp"]
rsp_abd19 = data19["E : Resp"]
rsp_abd20 = data20["E : Resp"]
rsp_abd21 = data21["E : Resp"]
rsp_abd22 = data22["E : Resp"]
rsp_abd23 = data23["E : Resp"]
rsp_abd24 = data24["E : Resp"]
rsp_abd25 = data25["E : Resp"]
rsp_abd26 = data26["E : Resp"]
rsp_abd27 = data27["E : Resp"]
rsp_abd28 = data28["E : Resp"]
rsp_abd29 = data29["E : Resp"]
rsp_abd30 = data30["E : Resp"]
nk.signal_plot(rsp_abd1, sampling_rate=16)

# %%
# Clean signal
cleaned_abd1 = nk.rsp_clean(rsp_abd1, sampling_rate=16)
cleaned_abd2 = nk.rsp_clean(rsp_abd2, sampling_rate=16)
cleaned_abd3 = nk.rsp_clean(rsp_abd3, sampling_rate=16)
cleaned_abd4 = nk.rsp_clean(rsp_abd4, sampling_rate=16)
cleaned_abd5 = nk.rsp_clean(rsp_abd5, sampling_rate=16)
cleaned_abd6 = nk.rsp_clean(rsp_abd6, sampling_rate=16)
cleaned_abd7 = nk.rsp_clean(rsp_abd7, sampling_rate=16)
cleaned_abd8 = nk.rsp_clean(rsp_abd8, sampling_rate=16)
cleaned_abd9 = nk.rsp_clean(rsp_abd9, sampling_rate=16)
cleaned_abd10 = nk.rsp_clean(rsp_abd10, sampling_rate=16)
cleaned_abd11 = nk.rsp_clean(rsp_abd11, sampling_rate=16)
cleaned_abd12 = nk.rsp_clean(rsp_abd12, sampling_rate=16)
cleaned_abd13 = nk.rsp_clean(rsp_abd13, sampling_rate=16)
cleaned_abd14 = nk.rsp_clean(rsp_abd14, sampling_rate=16)
cleaned_abd15 = nk.rsp_clean(rsp_abd15, sampling_rate=16)
cleaned_abd16 = nk.rsp_clean(rsp_abd16, sampling_rate=16)
cleaned_abd17 = nk.rsp_clean(rsp_abd17, sampling_rate=16)
cleaned_abd18 = nk.rsp_clean(rsp_abd18, sampling_rate=16)
cleaned_abd19 = nk.rsp_clean(rsp_abd19, sampling_rate=16)
cleaned_abd20 = nk.rsp_clean(rsp_abd20, sampling_rate=16)
cleaned_abd21 = nk.rsp_clean(rsp_abd21, sampling_rate=16)
cleaned_abd22 = nk.rsp_clean(rsp_abd22, sampling_rate=16)
cleaned_abd23 = nk.rsp_clean(rsp_abd23, sampling_rate=16)
cleaned_abd24 = nk.rsp_clean(rsp_abd24, sampling_rate=16)
cleaned_abd25 = nk.rsp_clean(rsp_abd25, sampling_rate=16)
cleaned_abd26 = nk.rsp_clean(rsp_abd26, sampling_rate=16)
cleaned_abd27 = nk.rsp_clean(rsp_abd27, sampling_rate=16)
cleaned_abd28 = nk.rsp_clean(rsp_abd28, sampling_rate=16)
cleaned_abd29 = nk.rsp_clean(rsp_abd29, sampling_rate=16)
cleaned_abd30 = nk.rsp_clean(rsp_abd30, sampling_rate=16)

# Extract peaks
df1, peaks_dict1 = nk.rsp_peaks(cleaned_abd1) 
df2, peaks_dict2 = nk.rsp_peaks(cleaned_abd2) 
df3, peaks_dict3 = nk.rsp_peaks(cleaned_abd3) 
df4, peaks_dict4 = nk.rsp_peaks(cleaned_abd4) 
df5, peaks_dict5 = nk.rsp_peaks(cleaned_abd5) 
df6, peaks_dict6 = nk.rsp_peaks(cleaned_abd6) 
df7, peaks_dict7 = nk.rsp_peaks(cleaned_abd7) 
df8, peaks_dict8 = nk.rsp_peaks(cleaned_abd8) 
df9, peaks_dict9 = nk.rsp_peaks(cleaned_abd9) 
df10, peaks_dict10 = nk.rsp_peaks(cleaned_abd10) 
df11, peaks_dict11 = nk.rsp_peaks(cleaned_abd11) 
df12, peaks_dict12 = nk.rsp_peaks(cleaned_abd12) 
df13, peaks_dict13 = nk.rsp_peaks(cleaned_abd13) 
df14, peaks_dict14 = nk.rsp_peaks(cleaned_abd14) 
df15, peaks_dict15 = nk.rsp_peaks(cleaned_abd15) 
df16, peaks_dict16 = nk.rsp_peaks(cleaned_abd16) 
df17, peaks_dict17 = nk.rsp_peaks(cleaned_abd17) 
df18, peaks_dict18 = nk.rsp_peaks(cleaned_abd18) 
df19, peaks_dict19 = nk.rsp_peaks(cleaned_abd19) 
df20, peaks_dict20 = nk.rsp_peaks(cleaned_abd20) 
df21, peaks_dict21 = nk.rsp_peaks(cleaned_abd21) 
df22, peaks_dict22 = nk.rsp_peaks(cleaned_abd22) 
df23, peaks_dict23 = nk.rsp_peaks(cleaned_abd23) 
df24, peaks_dict24 = nk.rsp_peaks(cleaned_abd24) 
df25, peaks_dict25 = nk.rsp_peaks(cleaned_abd25) 
df26, peaks_dict26 = nk.rsp_peaks(cleaned_abd26) 
df27, peaks_dict27 = nk.rsp_peaks(cleaned_abd27) 
df28, peaks_dict28 = nk.rsp_peaks(cleaned_abd28) 
df29, peaks_dict29 = nk.rsp_peaks(cleaned_abd29) 
df30, peaks_dict30 = nk.rsp_peaks(cleaned_abd30)

info1 = nk.rsp_fixpeaks(peaks_dict1)
info2 = nk.rsp_fixpeaks(peaks_dict2)
info3 = nk.rsp_fixpeaks(peaks_dict3)
info4 = nk.rsp_fixpeaks(peaks_dict4)
info5 = nk.rsp_fixpeaks(peaks_dict5)
info6 = nk.rsp_fixpeaks(peaks_dict6)
info7 = nk.rsp_fixpeaks(peaks_dict7)
info8 = nk.rsp_fixpeaks(peaks_dict8)
info9 = nk.rsp_fixpeaks(peaks_dict9)
info10 = nk.rsp_fixpeaks(peaks_dict10)
info11 = nk.rsp_fixpeaks(peaks_dict11)
info12 = nk.rsp_fixpeaks(peaks_dict12)
info13 = nk.rsp_fixpeaks(peaks_dict13)
info14 = nk.rsp_fixpeaks(peaks_dict14)
info15 = nk.rsp_fixpeaks(peaks_dict15)
info16 = nk.rsp_fixpeaks(peaks_dict16)
info17 = nk.rsp_fixpeaks(peaks_dict17)
info18 = nk.rsp_fixpeaks(peaks_dict18)
info19 = nk.rsp_fixpeaks(peaks_dict19)
info20 = nk.rsp_fixpeaks(peaks_dict20)
info21 = nk.rsp_fixpeaks(peaks_dict21)
info22 = nk.rsp_fixpeaks(peaks_dict22)
info23 = nk.rsp_fixpeaks(peaks_dict23)
info24 = nk.rsp_fixpeaks(peaks_dict24)
info25 = nk.rsp_fixpeaks(peaks_dict25)
info26 = nk.rsp_fixpeaks(peaks_dict26)
info27 = nk.rsp_fixpeaks(peaks_dict27)
info28 = nk.rsp_fixpeaks(peaks_dict28)
info29 = nk.rsp_fixpeaks(peaks_dict29)
info30 = nk.rsp_fixpeaks(peaks_dict30)
formatted1 = nk.signal_formatpeaks(info1, desired_length=len(cleaned_abd1),peak_indices=info1["RSP_Peaks"])
formatted2 = nk.signal_formatpeaks(info2, desired_length=len(cleaned_abd2),peak_indices=info2["RSP_Peaks"])
formatted3 = nk.signal_formatpeaks(info3, desired_length=len(cleaned_abd3),peak_indices=info3["RSP_Peaks"])
formatted4 = nk.signal_formatpeaks(info4, desired_length=len(cleaned_abd4),peak_indices=info4["RSP_Peaks"])
formatted5 = nk.signal_formatpeaks(info5, desired_length=len(cleaned_abd5),peak_indices=info5["RSP_Peaks"])
formatted6 = nk.signal_formatpeaks(info6, desired_length=len(cleaned_abd6),peak_indices=info6["RSP_Peaks"])
formatted7 = nk.signal_formatpeaks(info7, desired_length=len(cleaned_abd7),peak_indices=info7["RSP_Peaks"])
formatted8 = nk.signal_formatpeaks(info8, desired_length=len(cleaned_abd8),peak_indices=info8["RSP_Peaks"])
formatted9 = nk.signal_formatpeaks(info9, desired_length=len(cleaned_abd9),peak_indices=info9["RSP_Peaks"])
formatted10 = nk.signal_formatpeaks(info10, desired_length=len(cleaned_abd10),peak_indices=info10["RSP_Peaks"])
formatted11 = nk.signal_formatpeaks(info11, desired_length=len(cleaned_abd11),peak_indices=info11["RSP_Peaks"])
formatted12 = nk.signal_formatpeaks(info12, desired_length=len(cleaned_abd12),peak_indices=info12["RSP_Peaks"])
formatted13 = nk.signal_formatpeaks(info13, desired_length=len(cleaned_abd13),peak_indices=info13["RSP_Peaks"])
formatted14 = nk.signal_formatpeaks(info14, desired_length=len(cleaned_abd14),peak_indices=info14["RSP_Peaks"])
formatted15 = nk.signal_formatpeaks(info15, desired_length=len(cleaned_abd15),peak_indices=info15["RSP_Peaks"])
formatted16 = nk.signal_formatpeaks(info16, desired_length=len(cleaned_abd16),peak_indices=info16["RSP_Peaks"])
formatted17 = nk.signal_formatpeaks(info17, desired_length=len(cleaned_abd17),peak_indices=info17["RSP_Peaks"])
formatted18 = nk.signal_formatpeaks(info18, desired_length=len(cleaned_abd18),peak_indices=info18["RSP_Peaks"])
formatted19 = nk.signal_formatpeaks(info19, desired_length=len(cleaned_abd19),peak_indices=info19["RSP_Peaks"])
formatted20 = nk.signal_formatpeaks(info20, desired_length=len(cleaned_abd20),peak_indices=info20["RSP_Peaks"])
formatted21 = nk.signal_formatpeaks(info21, desired_length=len(cleaned_abd21),peak_indices=info21["RSP_Peaks"])
formatted22 = nk.signal_formatpeaks(info22, desired_length=len(cleaned_abd22),peak_indices=info22["RSP_Peaks"])
formatted23 = nk.signal_formatpeaks(info23, desired_length=len(cleaned_abd23),peak_indices=info23["RSP_Peaks"])
formatted24 = nk.signal_formatpeaks(info24, desired_length=len(cleaned_abd24),peak_indices=info24["RSP_Peaks"])
formatted25 = nk.signal_formatpeaks(info25, desired_length=len(cleaned_abd25),peak_indices=info25["RSP_Peaks"])
formatted26 = nk.signal_formatpeaks(info26, desired_length=len(cleaned_abd26),peak_indices=info26["RSP_Peaks"])
formatted27 = nk.signal_formatpeaks(info27, desired_length=len(cleaned_abd27),peak_indices=info27["RSP_Peaks"])
formatted28 = nk.signal_formatpeaks(info28, desired_length=len(cleaned_abd28),peak_indices=info28["RSP_Peaks"])
formatted29 = nk.signal_formatpeaks(info29, desired_length=len(cleaned_abd29),peak_indices=info29["RSP_Peaks"])
formatted30 = nk.signal_formatpeaks(info30, desired_length=len(cleaned_abd30),peak_indices=info30["RSP_Peaks"])

# %%
nk.signal_plot(pd.DataFrame({"RSP_Raw":rsp_abd1, "RSP_Clean": cleaned_abd1}), sampling_rate=16, subplots=True)

# %%
Abd_peaks = nk.events_plot(peaks_dict1['RSP_Peaks'], cleaned_abd1)

# %%
# Extract rate
rsp_abd_rate = nk.rsp_rate(cleaned_abd1, peaks_dict1, sampling_rate=16)

# Visualize
nk.signal_plot(rsp_abd_rate, sampling_rate=16)
plt.ylabel('Breaths Per Minute')
# Out:
# Text(0, 0.5, 'Breaths Per Minute')

# %%
rrv = nk.rsp_rrv(rsp_abd_rate, info1, sampling_rate=16, show=True)

# %%
df1, info1 = nk.bio_process(rsp= data1["E : Resp"], sampling_rate=16)
df2, info2 = nk.bio_process(rsp= data2["E : Resp"], sampling_rate=16)
df3, info3 = nk.bio_process(rsp= data3["E : Resp"], sampling_rate=16)
df4, info4 = nk.bio_process(rsp= data4["E : Resp"], sampling_rate=16)
df5, info5 = nk.bio_process(rsp= data5["E : Resp"], sampling_rate=16)
df6, info6 = nk.bio_process(rsp= data6["E : Resp"], sampling_rate=16)
df7, info7 = nk.bio_process(rsp= data7["E : Resp"], sampling_rate=16)
df8, info8 = nk.bio_process(rsp= data8["E : Resp"], sampling_rate=16)
df9, info9 = nk.bio_process(rsp= data9["E : Resp"], sampling_rate=16)
df10, info10 = nk.bio_process(rsp= data10["E : Resp"], sampling_rate=16)
df11, info11 = nk.bio_process(rsp= data11["E : Resp"], sampling_rate=16)
df12, info12 = nk.bio_process(rsp= data12["E : Resp"], sampling_rate=16)
df13, info13 = nk.bio_process(rsp= data13["E : Resp"], sampling_rate=16)
df14, info14 = nk.bio_process(rsp= data14["E : Resp"], sampling_rate=16)
df15, info15 = nk.bio_process(rsp= data15["E : Resp"], sampling_rate=16)
df16, info16 = nk.bio_process(rsp= data16["E : Resp"], sampling_rate=16)
df17, info17 = nk.bio_process(rsp= data17["E : Resp"], sampling_rate=16)
df18, info18 = nk.bio_process(rsp= data18["E : Resp"], sampling_rate=16)
df19, info19 = nk.bio_process(rsp= data19["E : Resp"], sampling_rate=16)
df20, info20 = nk.bio_process(rsp= data20["E : Resp"], sampling_rate=16)
df21, info21 = nk.bio_process(rsp= data21["E : Resp"], sampling_rate=16)
df22, info22 = nk.bio_process(rsp= data22["E : Resp"], sampling_rate=16)
df23, info23 = nk.bio_process(rsp= data23["E : Resp"], sampling_rate=16)
df24, info24 = nk.bio_process(rsp= data24["E : Resp"], sampling_rate=16)
df25, info25 = nk.bio_process(rsp= data25["E : Resp"], sampling_rate=16)
df26, info26 = nk.bio_process(rsp= data26["E : Resp"], sampling_rate=16)
df27, info27 = nk.bio_process(rsp= data27["E : Resp"], sampling_rate=16)
df28, info28 = nk.bio_process(rsp= data28["E : Resp"], sampling_rate=16)
df29, info29 = nk.bio_process(rsp= data29["E : Resp"], sampling_rate=16)
df30, info30 = nk.bio_process(rsp= data30["E : Resp"], sampling_rate=16)
# Out:
# C:\Users\like1\.conda\envs\ml\lib\site-packages\neurokit2\signal\signal_period.py:68: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# C:\Users\like1\.conda\envs\ml\lib\site-packages\neurokit2\rsp\rsp_symmetry.py:90: NeuroKitWarning: Not enough peaks and troughs (signal too short?) to compute symmetry, returning nan for symmetry.
#   warn(
# C:\Users\like1\.conda\envs\ml\lib\site-packages\neurokit2\signal\signal_period.py:68: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# C:\Users\like1\.conda\envs\ml\lib\site-packages\neurokit2\rsp\rsp_symmetry.py:90: NeuroKitWarning: Not enough peaks and troughs (signal too short?) to compute symmetry, returning nan for symmetry.
#   warn(

# %%
events1 = nk.events_find(data1["participant"], threshold_keep='below')
events2 = nk.events_find(data2["participant"], threshold_keep='below')
events3 = nk.events_find(data3["participant"], threshold_keep='below')
events4 = nk.events_find(data4["participant"], threshold_keep='below')
events5 = nk.events_find(data5["participant"], threshold_keep='below')
events6 = nk.events_find(data6["participant"], threshold_keep='below')
events7 = nk.events_find(data7["participant"], threshold_keep='below')
events8 = nk.events_find(data8["participant"], threshold_keep='below')
events9 = nk.events_find(data9["participant"], threshold_keep='below')
events10 = nk.events_find(data10["participant"], threshold_keep='below')
events11 = nk.events_find(data11["participant"], threshold_keep='below')
events12 = nk.events_find(data12["participant"], threshold_keep='below')
events13 = nk.events_find(data13["participant"], threshold_keep='below')
events14 = nk.events_find(data14["participant"], threshold_keep='below')
events15 = nk.events_find(data15["participant"], threshold_keep='below')
events16 = nk.events_find(data16["participant"], threshold_keep='below')
events17 = nk.events_find(data17["participant"], threshold_keep='below')
events18 = nk.events_find(data18["participant"], threshold_keep='below')
events19 = nk.events_find(data19["participant"], threshold_keep='below')
events20 = nk.events_find(data20["participant"], threshold_keep='below')
events21 = nk.events_find(data21["participant"], threshold_keep='below')
events22 = nk.events_find(data22["participant"], threshold_keep='below')
events23 = nk.events_find(data23["participant"], threshold_keep='below')
events24 = nk.events_find(data24["participant"], threshold_keep='below')
events25 = nk.events_find(data25["participant"], threshold_keep='below')
events26 = nk.events_find(data26["participant"], threshold_keep='below')
events27 = nk.events_find(data27["participant"], threshold_keep='below')
events28 = nk.events_find(data28["participant"], threshold_keep='below')
events29 = nk.events_find(data29["participant"], threshold_keep='below')
events30 = nk.events_find(data30["participant"], threshold_keep='below')

# %%
epochs2_1 = nk.epochs_create(df1, events1, sampling_rate=16)
epochs2_2 = nk.epochs_create(df2, events2, sampling_rate=16)
epochs2_3 = nk.epochs_create(df3, events3, sampling_rate=16)
epochs2_4 = nk.epochs_create(df4, events4, sampling_rate=16)
epochs2_5 = nk.epochs_create(df5, events5, sampling_rate=16)
epochs2_6 = nk.epochs_create(df6, events6, sampling_rate=16)
epochs2_7 = nk.epochs_create(df7, events7, sampling_rate=16)
epochs2_8 = nk.epochs_create(df8, events8, sampling_rate=16)
epochs2_9 = nk.epochs_create(df9, events9, sampling_rate=16)
epochs2_10 = nk.epochs_create(df10, events10, sampling_rate=16)
epochs2_11 = nk.epochs_create(df11, events11, sampling_rate=16)
epochs2_12 = nk.epochs_create(df12, events12, sampling_rate=16)
epochs2_13 = nk.epochs_create(df13, events13, sampling_rate=16)
epochs2_14 = nk.epochs_create(df14, events14, sampling_rate=16)
epochs2_15 = nk.epochs_create(df15, events15, sampling_rate=16)
epochs2_16 = nk.epochs_create(df16, events16, sampling_rate=16)
epochs2_17 = nk.epochs_create(df17, events17, sampling_rate=16)
epochs2_18 = nk.epochs_create(df18, events18, sampling_rate=16)
epochs2_19 = nk.epochs_create(df19, events19, sampling_rate=16)
epochs2_20 = nk.epochs_create(df20, events20, sampling_rate=16)
epochs2_21 = nk.epochs_create(df21, events21, sampling_rate=16)
epochs2_22 = nk.epochs_create(df22, events22, sampling_rate=16)
epochs2_23 = nk.epochs_create(df23, events23, sampling_rate=16)
epochs2_24 = nk.epochs_create(df24, events24, sampling_rate=16)
epochs2_25 = nk.epochs_create(df25, events25, sampling_rate=16)
epochs2_26 = nk.epochs_create(df26, events26, sampling_rate=16)
epochs2_27 = nk.epochs_create(df27, events27, sampling_rate=16)
epochs2_28 = nk.epochs_create(df28, events28, sampling_rate=16)
epochs2_29 = nk.epochs_create(df29, events29, sampling_rate=16)
epochs2_30 = nk.epochs_create(df30, events30, sampling_rate=16)

# %%
result2_1 = nk.rsp_eventrelated(epochs2_1)
result2_2 = nk.rsp_eventrelated(epochs2_2)
result2_3 = nk.rsp_eventrelated(epochs2_3)
result2_4 = nk.rsp_eventrelated(epochs2_4)
result2_5 = nk.rsp_eventrelated(epochs2_5)
result2_6 = nk.rsp_eventrelated(epochs2_6)
result2_7 = nk.rsp_eventrelated(epochs2_7)
result2_8 = nk.rsp_eventrelated(epochs2_8)
result2_9 = nk.rsp_eventrelated(epochs2_9)
result2_10 = nk.rsp_eventrelated(epochs2_10)
result2_11 = nk.rsp_eventrelated(epochs2_11)
result2_12 = nk.rsp_eventrelated(epochs2_12)
result2_13 = nk.rsp_eventrelated(epochs2_13)
result2_14 = nk.rsp_eventrelated(epochs2_14)
result2_15 = nk.rsp_eventrelated(epochs2_15)
result2_16 = nk.rsp_eventrelated(epochs2_16)
result2_17 = nk.rsp_eventrelated(epochs2_17)
result2_18 = nk.rsp_eventrelated(epochs2_18)
result2_19 = nk.rsp_eventrelated(epochs2_19)
result2_20 = nk.rsp_eventrelated(epochs2_20)
result2_21 = nk.rsp_eventrelated(epochs2_21)
result2_22 = nk.rsp_eventrelated(epochs2_22)
result2_23 = nk.rsp_eventrelated(epochs2_23)
result2_24 = nk.rsp_eventrelated(epochs2_24)
result2_25 = nk.rsp_eventrelated(epochs2_25)
result2_26 = nk.rsp_eventrelated(epochs2_26)
result2_27 = nk.rsp_eventrelated(epochs2_27)
result2_28 = nk.rsp_eventrelated(epochs2_28)
result2_29 = nk.rsp_eventrelated(epochs2_29)
result2_30 = nk.rsp_eventrelated(epochs2_30)
# Out:
# C:\Users\like1\.conda\envs\ml\lib\site-packages\neurokit2\epochs\eventrelated_utils.py:30: NeuroKitWarning: rsp_eventrelated(): The duration of your epochs seems quite long. You might want to use rsp_intervalrelated().
#   warn(
# C:\Users\like1\.conda\envs\ml\lib\site-packages\neurokit2\epochs\eventrelated_utils.py:30: NeuroKitWarning: rsp_eventrelated(): The duration of your epochs seems quite long. You might want to use rsp_intervalrelated().
#   warn(
# C:\Users\like1\.conda\envs\ml\lib\site-packages\neurokit2\epochs\eventrelated_utils.py:30: NeuroKitWarning: rsp_eventrelated(): The duration of your epochs seems quite long. You might want to use rsp_intervalrelated().
#   warn(
# C:\Users\like1\.conda\envs\ml\lib\site-packages\neurokit2\epochs\eventrelated_utils.py:30: NeuroKitWarning: rsp_eventrelated(): The duration of your epochs seems quite long. You might want to use rsp_intervalrelated().
#   warn(
# ...

# %%
result_df = pd.concat([result2_1, result2, result3, result4, result5, result6, result7, result8, result9, result10, result11, result12, result13, result14, result15, result16, result17, result19, result20, result21, result22, result23, result24, result25, result26, result27, result28, result29, result30], axis=0)
result_df.to_csv("P1_腹式呼吸_再次謝謝冠哲.csv",index=False)

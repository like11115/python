# %%
import pandas as pd
import csv
import os

# %%
for i in range(1,31):
    locals()['file_a'+str(i)] =pd.read_csv(f'一幀_{i}01.mp4.csv')#改range或檔名

# %%
files =[file_a1, file_a2, file_a3, file_a4, file_a5, file_a6, file_a7, file_a8, file_a9, file_a10,file_a11, file_a12, file_a13, file_a14, file_a15, file_a16, file_a17, file_a18, file_a19, file_a20,file_a21, file_a22, file_a23, file_a24, file_a25, file_a26, file_a27, file_a28, file_a29, file_a30]
for file in files:
    file.dropna(axis=0, thresh=20, inplace=True)#刪空值，數量照上面給的調，正常不用動

# %%
df_list=[1, 3, 12, 21, 30, 39, 48, 57, 66, 75, 84, 4, 13, 22, 31, 40, 49, 58, 67, 76, 85, 5, 14, 23, 32, 41, 50, 59, 68, 77, 86, 6, 15, 24, 33, 42, 51, 60, 69, 78, 87, 7, 16, 25, 34, 43, 52, 61, 70, 79, 88, 8, 17, 26, 35, 44, 53, 62, 71, 80, 89, 9, 18, 27, 36, 45, 54, 63, 72, 81, 90, 10, 19, 28, 37, 46, 55, 64, 73, 82, 91, 2, 11, 20, 29, 38, 47, 56, 65, 74, 83]
#第一次
file_a1.to_excel('file_a1.xlsx')
df1= pd.read_excel('file_a1.xlsx', sheet_name=0, header=None, usecols='B:CN')
df1 = df1[df_list]
df1.to_excel('第1部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a1.xlsx')
#第二次
file_a2.to_excel('file_a2.xlsx')
df2 = pd.read_excel('file_a2.xlsx', sheet_name=0, header=None, usecols='B:CN')
df2 = df2[df_list]
df2.to_excel('第2部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a2.xlsx')
#第三次
file_a3.to_excel('file_a3.xlsx')
df3 = pd.read_excel('file_a3.xlsx', sheet_name=0, header=None, usecols='B:CN')
df3 = df3[df_list]
df3.to_excel('第3部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a3.xlsx')
#第四次
file_a4.to_excel('file_a4.xlsx')
df4 = pd.read_excel('file_a4.xlsx', sheet_name=0, header=None, usecols='B:CN')
df4 = df4[df_list]
df4.to_excel('第4部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a4.xlsx')
#第五次
file_a5.to_excel('file_a5.xlsx')
df5 = pd.read_excel('file_a5.xlsx', sheet_name=0, header=None, usecols='B:CN')
df5 = df5[df_list]
df5.to_excel('第5部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a5.xlsx')
#第6次
file_a6.to_excel('file_a6.xlsx')
df6 = pd.read_excel('file_a6.xlsx', sheet_name=0, header=None, usecols='B:CN')
df6 = df6[df_list]
df6.to_excel('第6部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a6.xlsx')
#第7次
file_a7.to_excel('file_a7.xlsx')
df7 = pd.read_excel('file_a7.xlsx', sheet_name=0, header=None, usecols='B:CN')
df7 = df7[df_list]
df7.to_excel('第7部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a7.xlsx')
#第8次
file_a8.to_excel('file_a8.xlsx')
df8 = pd.read_excel('file_a8.xlsx', sheet_name=0, header=None, usecols='B:CN')
df8 = df8[df_list]
df8.to_excel('第8部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a8.xlsx')
#第9次
file_a9.to_excel('file_a9.xlsx')
df9 = pd.read_excel('file_a9.xlsx', sheet_name=0, header=None, usecols='B:CN')
df9 = df9[df_list]
df9.to_excel('第9部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a9.xlsx')
#第10次
file_a10.to_excel('file_a10.xlsx')
df10 = pd.read_excel('file_a10.xlsx', sheet_name=0, header=None, usecols='B:CN')
df10 = df10[df_list]
df10.to_excel('第10部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a10.xlsx')
#第11次
file_a11.to_excel('file_a11.xlsx')
df11 = pd.read_excel('file_a11.xlsx', sheet_name=0, header=None, usecols='B:CN')
df11 = df11[df_list]
df11.to_excel('第11部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a11.xlsx')
#第12次
file_a12.to_excel('file_a12.xlsx')
df12 = pd.read_excel('file_a12.xlsx', sheet_name=0, header=None, usecols='B:CN')
df12 = df12[df_list]
df12.to_excel('第12部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a12.xlsx')
#第13次
file_a13.to_excel('file_a13.xlsx')
df13 = pd.read_excel('file_a13.xlsx', sheet_name=0, header=None, usecols='B:CN')
df13 = df13[df_list]
df13.to_excel('第13部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a13.xlsx')
#第14次
file_a14.to_excel('file_a14.xlsx')
df14 = pd.read_excel('file_a14.xlsx', sheet_name=0, header=None, usecols='B:CN')
df14 = df14[df_list]
df14.to_excel('第14部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a14.xlsx')
#第15次
file_a15.to_excel('file_a15.xlsx')
df15 = pd.read_excel('file_a15.xlsx', sheet_name=0, header=None, usecols='B:CN')
df15 = df15[df_list]
df15.to_excel('第15部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a15.xlsx')
#第16次
file_a16.to_excel('file_a16.xlsx')
df16 = pd.read_excel('file_a16.xlsx', sheet_name=0, header=None, usecols='B:CN')
df16 = df16[df_list]
df16.to_excel('第16部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a16.xlsx')
#第17次
file_a17.to_excel('file_a17.xlsx')
df17 = pd.read_excel('file_a17.xlsx', sheet_name=0, header=None, usecols='B:CN')
df17 = df17[df_list]
df17.to_excel('第17部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a17.xlsx')
#第18次
file_a18.to_excel('file_a18.xlsx')
df18 = pd.read_excel('file_a18.xlsx', sheet_name=0, header=None, usecols='B:CN')
df18 = df18[df_list]
df18.to_excel('第18部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a18.xlsx')
#第19次
file_a19.to_excel('file_a19.xlsx')
df19 = pd.read_excel('file_a19.xlsx', sheet_name=0, header=None, usecols='B:CN')
df19 = df19[df_list]
df19.to_excel('第19部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a19.xlsx')
#第20次
file_a20.to_excel('file_a20.xlsx')
df20 = pd.read_excel('file_a20.xlsx', sheet_name=0, header=None, usecols='B:CN')
df20 = df20[df_list]
df20.to_excel('第20部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a20.xlsx')
#第21次
file_a21.to_excel('file_a21.xlsx')
df21= pd.read_excel('file_a21.xlsx', sheet_name=0, header=None, usecols='B:CN')
df21 = df21[df_list]
df21.to_excel('第21部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a21.xlsx')
#第22次
file_a22.to_excel('file_a22.xlsx')
df22 = pd.read_excel('file_a22.xlsx', sheet_name=0, header=None, usecols='B:CN')
df22 = df22[df_list]
df22.to_excel('第22部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a22.xlsx')
#第23次
file_a23.to_excel('file_a23.xlsx')
df23 = pd.read_excel('file_a23.xlsx', sheet_name=0, header=None, usecols='B:CN')
df23 = df23[df_list]
df23.to_excel('第23部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a23.xlsx')
#第24次
file_a24.to_excel('file_a24.xlsx')
df24 = pd.read_excel('file_a24.xlsx', sheet_name=0, header=None, usecols='B:CN')
df24 = df24[df_list]
df24.to_excel('第24部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a24.xlsx')
#第25次
file_a25.to_excel('file_a25.xlsx')
df25 = pd.read_excel('file_a25.xlsx', sheet_name=0, header=None, usecols='B:CN')
df25 = df25[df_list]
df25.to_excel('第25部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a25.xlsx')
#第26次
file_a26.to_excel('file_a26.xlsx')
df26 = pd.read_excel('file_a26.xlsx', sheet_name=0, header=None, usecols='B:CN')
df26 = df26[df_list]
df26.to_excel('第26部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a26.xlsx')
#第27次
file_a27.to_excel('file_a27.xlsx')
df27 = pd.read_excel('file_a27.xlsx', sheet_name=0, header=None, usecols='B:CN')
df27 = df27[df_list]
df27.to_excel('第27部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a27.xlsx')
#第28次
file_a28.to_excel('file_a28.xlsx')
df28 = pd.read_excel('file_a28.xlsx', sheet_name=0, header=None, usecols='B:CN')
df28 = df28[df_list]
df28.to_excel('第28部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a28.xlsx')
#第29次
file_a29.to_excel('file_a29.xlsx')
df29 = pd.read_excel('file_a29.xlsx', sheet_name=0, header=None, usecols='B:CN')
df29 = df29[df_list]
df29.to_excel('第29部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a29.xlsx')
#第30次
file_a30.to_excel('file_a30.xlsx')
df30 = pd.read_excel('file_a30.xlsx', sheet_name=0, header=None, usecols='B:CN')
df30 = df30[df_list]
df30.to_excel('第30部影片.xlsx', sheet_name='Sheet1', index=False, header=False)
os.remove('file_a30.xlsx')

# %%
#備用程式碼

# %%
file_a1 = pd.read_csv('一幀_101.mp4.csv')#檔名1
file_a2 = pd.read_csv('一幀_201.mp4.csv')#檔名2
file_a3 = pd.read_csv('一幀_301.mp4.csv')#檔名3
file_a4 = pd.read_csv('一幀_401.mp4.csv')#檔名4
file_a5 = pd.read_csv('一幀_501.mp4.csv')#檔名5
file_a6 = pd.read_csv('一幀_601.mp4.csv')#檔名6
file_a7 = pd.read_csv('一幀_701.mp4.csv')#檔名7
file_a8 = pd.read_csv('一幀_801.mp4.csv')#檔名8
file_a9 = pd.read_csv('一幀_901.mp4.csv')#檔名9
file_a10 = pd.read_csv('一幀_1001.mp4.csv')#檔名10
file_a11 = pd.read_csv('一幀_1101.mp4.csv')#檔名11
file_a12 = pd.read_csv('一幀_1201.mp4.csv')#檔名12
file_a13 = pd.read_csv('一幀_1301.mp4.csv')#檔名13
file_a14 = pd.read_csv('一幀_1401.mp4.csv')#檔名14
file_a15 = pd.read_csv('一幀_1501.mp4.csv')#檔名15
file_a16 = pd.read_csv('一幀_1601.mp4.csv')#檔名16
file_a17 = pd.read_csv('一幀_1701.mp4.csv')#檔名17
file_a18 = pd.read_csv('一幀_1801.mp4.csv')#檔名18
file_a19 = pd.read_csv('一幀_1901.mp4.csv')#檔名19
file_a20 = pd.read_csv('一幀_2001.mp4.csv')#檔名20
file_a21 = pd.read_csv('一幀_2101.mp4.csv')#檔名21
file_a22 = pd.read_csv('一幀_2201.mp4.csv')#檔名22
file_a23 = pd.read_csv('一幀_2301.mp4.csv')#檔名23
file_a24 = pd.read_csv('一幀_2401.mp4.csv')#檔名24
file_a25 = pd.read_csv('一幀_2501.mp4.csv')#檔名25
file_a26 = pd.read_csv('一幀_2601.mp4.csv')#檔名26
file_a27 = pd.read_csv('一幀_2701.mp4.csv')#檔名27
file_a28 = pd.read_csv('一幀_2801.mp4.csv')#檔名28
file_a29 = pd.read_csv('一幀_2901.mp4.csv')#檔名29
file_a30 = pd.read_csv('一幀_3001.mp4.csv')#檔名30

# %%
file_a1=file_a1.dropna(axis=0, thresh=20, inplace=True)#刪除空值
file_a2=file_a2.dropna(axis=0, thresh=20, inplace=True)file_a3=file_a3.dropna(axis=0, thresh=20, inplace=True)
file_a4=file_a4.dropna(axis=0, thresh=20, inplace=True)
file_a5=file_a5.dropna(axis=0, thresh=20, inplace=True)
file_a6=file_a6.dropna(axis=0, thresh=20, inplace=True)
file_a7=file_a7.dropna(axis=0, thresh=20, inplace=True)
file_a8=file_a8.dropna(axis=0, thresh=20, inplace=True)
file_a9=file_a9.dropna(axis=0, thresh=20, inplace=True)
file_a10=file_a10.dropna(axis=0, thresh=20, inplace=True)
file_a11=file_a11.dropna(axis=0, thresh=20, inplace=True)
file_a12=file_a12.dropna(axis=0, thresh=20, inplace=True)
file_a13=file_a13.dropna(axis=0, thresh=20, inplace=True)
file_a14=file_a14.dropna(axis=0, thresh=20, inplace=True)
file_a15=file_a15.dropna(axis=0, thresh=20, inplace=True)
file_a16=file_a16.dropna(axis=0, thresh=20, inplace=True)
file_a17=file_a17.dropna(axis=0, thresh=20, inplace=True)
file_a18=file_a18.dropna(axis=0, thresh=20, inplace=True)
file_a19=file_a19.dropna(axis=0, thresh=20, inplace=True)
file_a20=file_a20.dropna(axis=0, thresh=20, inplace=True)
file_a21=file_a21.dropna(axis=0, thresh=20, inplace=True)
file_a22=file_a22.dropna(axis=0, thresh=20, inplace=True)
file_a23=file_a23.dropna(axis=0, thresh=20, inplace=True)
file_a24=file_a24.dropna(axis=0, thresh=20, inplace=True)
file_a25=file_a25.dropna(axis=0, thresh=20, inplace=True)
file_a26=file_a26.dropna(axis=0, thresh=20, inplace=True)
file_a27=file_a27.dropna(axis=0, thresh=20, inplace=True)
file_a28=file_a28.dropna(axis=0, thresh=20, inplace=True)
file_a29=file_a29.dropna(axis=0, thresh=20, inplace=True)
file_a30=file_a30.dropna(axis=0, thresh=20, inplace=True)
